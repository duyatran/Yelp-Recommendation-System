# %% [markdown]
# # Testing the KNNBasic algorithm

# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)                                
import pickle
import os
import random

import pandas as pd

from surprise import KNNBasic
from surprise import KNNBaseline
from surprise import Dataset
from surprise import Reader
from surprise.accuracy import rmse

# %%
my_seed = 1
random.seed(my_seed)

reader = Reader(line_format='user item rating', sep=',')
train_file = '../output/trainData.txt'
test_file = '../output/testData.txt'
data = Dataset.load_from_folds([(train_file, test_file)], reader)

algo = KNNBasic()

for trainset, testset in data.folds():
    algo.train(trainset)                             
    predictions = algo.test(testset)
    rmse(predictions)
# Out:
# Computing the msd similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-992463f22bbc> in <module>()
#      10
#      11 for trainset, testset in data.folds():
# ---> 12     algo.train(trainset)
#      13     predictions = algo.test(testset)
#      14     rmse(predictions)
#
# /home/vagrant/miniconda/lib/python2.7/site-packages/surprise/prediction_algorithms/knns.pyc in train(self, trainset)
#      90
#      91         SymmetricAlgo.train(self, trainset)
# ---> 92         self.sim = self.compute_similarities()
#      93
#      94     def estimate(self, u, i):
#
# /home/vagrant/miniconda/lib/python2.7/site-packages/surprise/prediction_algorithms/algo_base.pyc in compute_similarities(self)
#     209         try:
#     210             print('Computing the {0} similarity matrix...'.format(name))
# --> 211             sim = construction_func[name](*args)
#     212             print('Done computing similarity matrix.')
#     213             return sim
#
# /home/vagrant/miniconda/lib/python2.7/site-packages/surprise/similarities.pyx in surprise.similarities.msd (surprise/similarities.c:3524)()
#     141     cdef int min_sprt = min_support
#     142
# --> 143     sq_diff = np.zeros((n_x, n_x), np.double)
#     144     freq = np.zeros((n_x, n_x), np.int)
#     145     sim = np.zeros((n_x, n_x), np.double)
#
# MemoryError:

# %%
# Build a pandas dataframe with all the predictions

def get_Iu(uid):
    """Return the number of items rated by given user
    
    Args:
        uid: The raw id of the user.
    Returns:
        The number of items rated by the user.
    """
    
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError:  # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """Return the number of users that have rated given item
    
    Args:
        iid: The raw id of the item.
    Returns:
        The number of users that have rated the item.
    """
    
    try:
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:  # item was not part of the trainset
        return 0

df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])    
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)

# %%
df.head()

# %%
best_predictions = df.sort_values(by='err')[:10]
worst_predictions = df.sort_values(by='err')[-10:]

# %%
# Let's take a look at the best predictions of the algorithm
best_predictions
# Out:
#                        uid                     iid  rui       est  \
# 69  XJYFjbH-oTmu2dATTqyauQ  0x2qB4R790SX3W4W8FQuWA  4.0  4.001405
# 48  tRY6Y1sVehnJ2h3IsHcbnQ  0x2qB4R790SX3W4W8FQuWA  4.0  4.001405
# 13  d_TBs6J3twMy9GChqUEXkg  0x2qB4R790SX3W4W8FQuWA  4.0  4.001405
# 65  C0jquh-km5UnawqDqSQpBw  4uiijOUDzc-DeIb2XcKW_A  3.0  2.942759
# 42  0lDl1Jg1Qz2KhvkfJKk6fw  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
# 90  Yej5B4nd8PqpHMQcmCTDrg  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
# 47  hfuhalehYPI89JCRSW1mSA  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
# 53  85gI4BQZ9zMtqkQ33niGWw  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
# 76  xH-vP1j0jR_BEdWcBkjDQg  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
# 82  dIIKEfOgo0KqUfGQvGikPg  4P1h3LKaCkgQL5dSy5d9gw  3.0  3.071899
#
#                        details  Iu  Ui       err
# 69  {u'was_impossible': False}   0  36  0.001405
# 48  {u'was_impossible': False}   0  36  0.001405
# 13  {u'was_impossible': False}   0  36  0.001405
# 65  {u'was_impossible': False}   0  28  0.057241
# 42  {u'was_impossible': False}   0  42  0.071899
# 90  {u'was_impossible': False}   0  42  0.071899
# 47  {u'was_impossible': False}   0  42  0.071899
# 53  {u'was_impossible': False}   0  42  0.071899
# 76  {u'was_impossible': False}   0  42  0.071899
# 82  {u'was_impossible': False}   0  42  0.071899

# %% [markdown]
# It's interesting to note that these perfect predictions are actually lucky shots: $|U_i|$ is always very small, meaning that very few users have rated the target item. This implies that the set of neighbors is very small (see the ``actual_k`` field)... And, it just happens that all the ratings from the neighbors are the same (and mostly, are equal to that of the target user).
#
# This may be a bit surprising but these lucky shots are actually very important to the accuracy of the algorithm... Try running the same algorithm with a value of ``min_k`` equal to $10$. This means that if there are less than $10$ neighbors, the prediction is set to the mean of all ratings. You'll see your accuracy decrease!

# %%
# Now, let's look at the prediction with the biggest error
worst_predictions
# Out:
#                        uid                     iid  rui       est  \
# 3   W1Nl6_R7amuZ6NStXI3uBA  2PqCZxon6AZHJrQ5iam4LA  1.0  3.298947
# 54  p0RVQxuOSA2NV4Odv_kgWQ  32S_SP-ZaVmQucdEY5ynlQ  1.0  3.377895
# 46  3iq8oDotfNXL57CbqzaaAA  32S_SP-ZaVmQucdEY5ynlQ  1.0  3.377895
# 43  ub50UE95-gu7yIoed1zssA  4P-vTvE6cncJyUyLh73pxw  1.0  3.389880
# 67  -d8tk22ca-MpY7htQIw08Q  29XtLRA0y7Nfi4eZF-ZI4A  1.0  3.475882
# 86  1-0K54tp4ig3lYjd1eRF_g  8KWWHywMjN-154i_Qi0deQ  1.0  3.517000
# 20  T-6kD-3JWxzC9QszSa1e6A  8reh8dD3VasFglGhlkNlgg  1.0  3.542500
# 1   SxV1Jq7UANuSYpn42JXvOA  -3pfhzz9CB7F2DpbF1Ko7Q  1.0  3.667429
# 59  7BT9J9gmv3GsesY7Ju7pXA  0BJK4_RQnNiiXJcYPEgG3w  1.0  3.766283
# 24  9sdni8QHrai8l7ikHsV5Jg  7GI_V9oLCUGdn2ogqB0IBg  1.0  3.772632
#
#                        details  Iu  Ui       err
# 3   {u'was_impossible': False}   0   2  2.298947
# 54  {u'was_impossible': False}   0   2  2.377895
# 46  {u'was_impossible': False}   0   2  2.377895
# 43  {u'was_impossible': False}   0  17  2.389880
# 67  {u'was_impossible': False}   0  12  2.475882
# 86  {u'was_impossible': False}   0  16  2.517000
# 20  {u'was_impossible': False}   0   0  2.542500
# 1   {u'was_impossible': False}   0   1  2.667429
# 59  {u'was_impossible': False}   0  53  2.766283
# 24  {u'was_impossible': False}   0   2  2.772632

# %% [markdown]
# Let's focus first on the last two predictions. Well, we can't do much about them. We should have predicted $5$, but the only available neighbor had a rating of $1$, so we were screwed. The only way to avoid this kind of errors would be to increase the ``min_k`` parameter, but it would actually worsen the accuracy (see note above).
#
# How about the other ones? It seems that for each prediction, the users are some kind of outsiders: they rated their item with a rating of $1$ when the most of the ratings for the item where high (or inversely, rated a *bad* item with a rating of $5$). See the plot below as an illustration for the first rating.
#
# These are situations where baseline estimates would be quite helpful, in order to deal with highly biased users (and items).

# %%
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
matplotlib.style.use('ggplot')

counter = Counter([r for (_, r) in trainset.ir[trainset.to_inner_iid('302')]])
pd.DataFrame.from_dict(counter, orient='index').plot(kind='bar', legend=False)
plt.xlabel('Rating value')
plt.ylabel('Number of users')
plt.title('Number of users having rated item 302')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2eb6544d86a7> in <module>()
#       6 matplotlib.style.use('ggplot')
#       7
# ----> 8 counter = Counter([r for (_, r) in trainset.ir[trainset.to_inner_iid('302')]])
#       9 pd.DataFrame.from_dict(counter, orient='index').plot(kind='bar', legend=False)
#      10 plt.xlabel('Rating value')
#
# /home/vagrant/miniconda/lib/python2.7/site-packages/surprise/dataset.pyc in to_inner_iid(self, riid)
#     562         except KeyError:
#     563             raise ValueError(('Item ' + str(riid) +
# --> 564                               ' is not part of the trainset.'))
#     565
#     566     def all_ratings(self):
#
# ValueError: Item 302 is not part of the trainset.
